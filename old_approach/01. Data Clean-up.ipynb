# %%
import pandas as pd
import numpy as np
import csv
import sqlite3
import re
import pickle

from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc

from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_path = './data/loan.csv'
date_to_parse = ['issue_d' , 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d', 'earliest_cr_line']

df=pd.read_csv(csv_path, date_parser=date_to_parse)
# Out:
# C:\Users\xzhou\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (887379, 74)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl',
#        'inq_last_12m'],
#       dtype='object')

# %%
filter = ['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 
          'emp_length', 'home_ownership', 'annual_inc', 'loan_status', 
          'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line', 
          'inq_last_6mths', 'mths_since_last_delinq', 
          'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 
          'revol_util', 'application_type', 'collections_12_mths_ex_med', 
          'mths_since_last_major_derog', 'policy_code', 'annual_inc_joint', 
          'dti_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 
          'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 
          'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 
          'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 
          'inq_fi', 'total_cu_tl','inq_last_12m']

# %%
df_smaller = df.filter(items=filter)

# %%
df_smaller.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'loan_status', 'purpose', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'application_type',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'annual_inc_joint', 'dti_joint', 'acc_now_delinq',
#        'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m',
#        'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il',
#        'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m'],
#       dtype='object')

# %%
df_smaller.isnull().sum()
# Out:
# loan_amnt                           0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# emp_length                      44825
# home_ownership                      0
# annual_inc                          4
# loan_status                         0
# purpose                             0
# dti                                 0
# delinq_2yrs                        29
# earliest_cr_line                   29
# inq_last_6mths                     29
# mths_since_last_delinq         454312
# mths_since_last_record         750326
# open_acc                           29
# pub_rec                            29
# revol_bal                           0
# revol_util                        502
# application_type                    0
# collections_12_mths_ex_med        145
# mths_since_last_major_derog    665676
# policy_code                         0
# annual_inc_joint               886868
# dti_joint                      886870
# acc_now_delinq                     29
# tot_coll_amt                    70276
# tot_cur_bal                     70276
# open_acc_6m                    866007
# open_il_6m                     866007
# open_il_12m                    866007
# open_il_24m                    866007
# mths_since_rcnt_il             866569
# total_bal_il                   866007
# il_util                        868762
# open_rv_12m                    866007
# open_rv_24m                    866007
# max_bal_bc                     866007
# all_util                       866007
# total_rev_hi_lim                70276
# inq_fi                         866007
# total_cu_tl                    866007
# inq_last_12m                   866007
# dtype: int64

# %%
# Drop the filds have 90%+ null values, 
# as filling in the nulls can skew the model

columns_to_drop = [
    'annual_inc_joint', 'dti_joint',  'open_acc_6m', 'open_il_6m',
    'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il',
    'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
    'inq_fi', 'total_cu_tl', 'inq_last_12m'
]

df_smaller.drop(columns_to_drop, axis=1, inplace=True)

# %%
df_smaller.rename(index=str, 
                  columns={"dti": "payment_to_income_ratio_individual"}, 
                  inplace=True)

# %%
df_clean = df_smaller.copy()

# %%
df_clean.isnull().sum()
# Out:
# loan_amnt                                  0
# term                                       0
# int_rate                                   0
# installment                                0
# grade                                      0
# emp_length                             44825
# home_ownership                             0
# annual_inc                                 4
# loan_status                                0
# purpose                                    0
# payment_to_income_ratio_individual         0
# delinq_2yrs                               29
# earliest_cr_line                          29
# inq_last_6mths                            29
# mths_since_last_delinq                454312
# mths_since_last_record                750326
# open_acc                                  29
# pub_rec                                   29
# revol_bal                                  0
# revol_util                               502
# application_type                           0
# collections_12_mths_ex_med               145
# mths_since_last_major_derog           665676
# policy_code                                0
# acc_now_delinq                            29
# tot_coll_amt                           70276
# tot_cur_bal                            70276
# total_rev_hi_lim                       70276
# dtype: int64

# %%
excluded = {'Issued', 'Does not meet the credit policy. Status:Charged Off',
            'Does not meet the credit policy. Status:Fully Paid'}
good = {'Current', 'Fully Paid'}
bad = {'Charged Off', 'Default', 'In Grace Period', 
       'Late (16-30 days)', 'Late (31-120 days)'}

def get_status(status):
    """
    Classify loans to either good or bad loans based on their status.
    """
    try: 
        status=status.strip()
        if status in good:
            return "good"
        elif status in bad:
            return "bad"
        else: 
            return "excluded"
    except: 
        return "excluded"

# %%
df_clean['loan_status'] = df_clean['loan_status'].apply(lambda x: get_status(x))

# %%
df_clean = df_clean[df_clean['loan_status'] != 'excluded']

# %%
df_clean.groupby('loan_status').count()
# Out:
#              loan_amnt    term  int_rate  installment   grade  emp_length  \
# loan_status
# bad              66668   66668     66668        66668   66668       62973
# good            809502  809502    809502       809502  809502      769037
#
#              home_ownership  annual_inc  purpose  \
# loan_status
# bad                   66668       66668    66668
# good                 809502      809502   809502
#
#              payment_to_income_ratio_individual        ...         revol_bal  \
# loan_status                                            ...
# bad                                       66668        ...             66668
# good                                     809502        ...            809502
#
#              revol_util  application_type  collections_12_mths_ex_med  \
# loan_status
# bad               66607             66668                       66662
# good             809104            809502                      809452
#
#              mths_since_last_major_derog  policy_code  acc_now_delinq  \
# loan_status
# bad                                15124        66668           66668
# good                              204054       809502          809502
#
#              tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# loan_status
# bad                 56417        56417             56417
# good               752226       752226            752226
#
# [2 rows x 27 columns]

# %%
# Fill the null value for 'mths_since_last_delinq' with zero as zero is default case for majority of loans

fill_with_zero = {
    'mths_since_last_delinq':0,
    'mths_since_last_record':0,
    'collections_12_mths_ex_med':0,
    'mths_since_last_major_derog':0,
    'tot_coll_amt':0
}
            
df_clean.fillna(fill_with_zero,inplace=True)

# %%
# Fill the null value for 'revol util' with means

df_clean['revol_util'].fillna(
    value=df_clean['revol_util'].mean(), inplace=True)

# %%
# Fill the null value for 'tot_cur_bal' with means

df_clean['tot_cur_bal'].fillna(
    value=df_clean['tot_cur_bal'].mean(), inplace=True)

# %%
# Fill the null value for 'total_rev_hi_lim' with means

df_clean['total_rev_hi_lim'].fillna(
    value=df_clean['total_rev_hi_lim'].mean(), inplace=True)

# %%
def get_employment_length(length):
    """
    This is to extract numerical value of emp_length
    For simplicity, approximation was used.
    <1 years will be treated as 1 year
    >10 years will be treated as 10 years
    """
    try:
        length = length.strip()
        year = re.findall(r'(\d+)', length)
        return int(year[0]) 
    except:
        return None

# %%
df_clean['emp_length'] = df_clean['emp_length'].apply(lambda x: get_employment_length(x))

# %%
df_clean['emp_length'].fillna(
    value=df_clean['emp_length'].mean(), inplace=True)

# %%
# All Null values have been appropriately handled.

df_clean.isnull().sum()
# Out:
# loan_amnt                             0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# emp_length                            0
# home_ownership                        0
# annual_inc                            0
# loan_status                           0
# purpose                               0
# payment_to_income_ratio_individual    0
# delinq_2yrs                           0
# earliest_cr_line                      0
# inq_last_6mths                        0
# mths_since_last_delinq                0
# mths_since_last_record                0
# open_acc                              0
# pub_rec                               0
# revol_bal                             0
# revol_util                            0
# application_type                      0
# collections_12_mths_ex_med            0
# mths_since_last_major_derog           0
# policy_code                           0
# acc_now_delinq                        0
# tot_coll_amt                          0
# tot_cur_bal                           0
# total_rev_hi_lim                      0
# dtype: int64

# %%
# Break down terms of loan into 2 categories.

df_clean = pd.get_dummies(df_clean, prefix=['term'], columns=['term'])

# %%
# Break down grades into categories.

df_clean = pd.get_dummies(df_clean, prefix=['grade'], columns=['grade'])

# %%
df_clean = pd.get_dummies(df_clean, prefix=['home_ownership'], columns=['home_ownership'])

# %%
df_clean[df_clean['loan_status'] == 'bad'].groupby('purpose').count()
# Out:
#                     loan_amnt  int_rate  installment  emp_length  annual_inc  \
# purpose
# car                       583       583          583         583         583
# credit_card             11686     11686        11686       11686       11686
# debt_consolidation      41316     41316        41316       41316       41316
# educational                56        56           56          56          56
# home_improvement         3482      3482         3482        3482        3482
# house                     406       406          406         406         406
# major_purchase           1271      1271         1271        1271        1271
# medical                   782       782          782         782         782
# moving                    592       592          592         592         592
# other                    4042      4042         4042        4042        4042
# renewable_energy           71        71           71          71          71
# small_business           1709      1709         1709        1709        1709
# vacation                  396       396          396         396         396
# wedding                   276       276          276         276         276
#
#                     loan_status  payment_to_income_ratio_individual  \
# purpose
# car                         583                                 583
# credit_card               11686                               11686
# debt_consolidation        41316                               41316
# educational                  56                                  56
# home_improvement           3482                                3482
# house                       406                                 406
# major_purchase             1271                                1271
# medical                     782                                 782
# moving                      592                                 592
# other                      4042                                4042
# renewable_energy             71                                  71
# small_business             1709                                1709
# vacation                    396                                 396
# wedding                     276                                 276
#
#                     delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# purpose
# car                         583               583             583
# credit_card               11686             11686           11686
# debt_consolidation        41316             41316           41316
# educational                  56                56              56
# home_improvement           3482              3482            3482
# house                       406               406             406
# major_purchase             1271              1271            1271
# medical                     782               782             782
# moving                      592               592             592
# other                      4042              4042            4042
# renewable_energy             71                71              71
# small_business             1709              1709            1709
# vacation                    396               396             396
# wedding                     276               276             276
#
#                            ...           grade_D  grade_E  grade_F  grade_G  \
# purpose                    ...
# car                        ...               583      583      583      583
# credit_card                ...             11686    11686    11686    11686
# debt_consolidation         ...             41316    41316    41316    41316
# educational                ...                56       56       56       56
# home_improvement           ...              3482     3482     3482     3482
# house                      ...               406      406      406      406
# major_purchase             ...              1271     1271     1271     1271
# medical                    ...               782      782      782      782
# moving                     ...               592      592      592      592
# other                      ...              4042     4042     4042     4042
# renewable_energy           ...                71       71       71       71
# small_business             ...              1709     1709     1709     1709
# vacation                   ...               396      396      396      396
# wedding                    ...               276      276      276      276
#
#                     home_ownership_ANY  home_ownership_MORTGAGE  \
# purpose
# car                                583                      583
# credit_card                      11686                    11686
# debt_consolidation               41316                    41316
# educational                         56                       56
# home_improvement                  3482                     3482
# house                              406                      406
# major_purchase                    1271                     1271
# medical                            782                      782
# moving                             592                      592
# other                             4042                     4042
# renewable_energy                    71                       71
# small_business                    1709                     1709
# vacation                           396                      396
# wedding                            276                      276
#
#                     home_ownership_NONE  home_ownership_OTHER  \
# purpose
# car                                 583                   583
# credit_card                       11686                 11686
# debt_consolidation                41316                 41316
# educational                          56                    56
# home_improvement                   3482                  3482
# house                               406                   406
# major_purchase                     1271                  1271
# medical                             782                   782
# moving                              592                   592
# other                              4042                  4042
# renewable_energy                     71                    71
# small_business                     1709                  1709
# vacation                            396                   396
# wedding                             276                   276
#
#                     home_ownership_OWN  home_ownership_RENT
# purpose
# car                                583                  583
# credit_card                      11686                11686
# debt_consolidation               41316                41316
# educational                         56                   56
# home_improvement                  3482                 3482
# house                              406                  406
# major_purchase                    1271                 1271
# medical                            782                  782
# moving                             592                  592
# other                             4042                 4042
# renewable_energy                    71                   71
# small_business                    1709                 1709
# vacation                           396                  396
# wedding                            276                  276
#
# [14 rows x 39 columns]

# %%
df_clean = pd.get_dummies(df_clean, prefix=['purpose'], columns=['purpose'])

# %%
def get_earliest_cr_line(string):
    """
    This is to calculate years of credit history.
    Since the data is from 2016, use 2016 minus the 
    starting year to estimate years of credit history.
    
    """
    string = string.strip()
    year = re.findall(r'(\d+)', string)
    return (2016-int(year[0]))

# %%
df_clean['earliest_cr_line'] = df_clean['earliest_cr_line'].apply(lambda x: get_earliest_cr_line(x))

# %%
def inverse(value):
    try:
        return 1 / value
    except: 
        return 0

# %%
# Take inverse of months since last delinquishing date as this is is inversed related to default prediction

df_clean['inversed_mths_since_last_delinq'] = df_clean['mths_since_last_delinq'].apply(lambda x: inverse(x))

# %%
# Take inverse of months since last record as this is is inversed related to default to default prediction

df_clean['inversed_mths_since_last_record'] = df_clean['mths_since_last_record'].apply(lambda x: inverse(x))

# %%
# Take inverse of months since last record as this is is inversed related to default to default prediction.
new_col_name = 'inversed_mths_since_last_major_derog'
old_col_name = 'mths_since_last_major_derog'
df_clean[new_col_name] = df_clean[old_col_name].apply(lambda x: inverse(x))

# %%
df_clean.drop(
    ['mths_since_last_delinq', 'mths_since_last_record',
     'mths_since_last_major_derog'], 
    inplace=True, axis=1)

# %%
# Calculate income-to-debt raio. 
# This can result in infinite values when revol_balance is small.

df_clean['income_to_debt_ratio'] = df_clean['annual_inc'] / df_clean['revol_bal']

# %%
# Replace infinite value with N/As.

df_clean['income_to_debt_ratio'] = df_clean['income_to_debt_ratio'].replace(np.inf, np.nan)

# %%
# Drop infinite values since size of it is very small.

df_clean = df_clean[df_clean['income_to_debt_ratio'] >= 0]

# %%
# Break down applicaiton type to different categories.

df_clean=pd.get_dummies(df_clean, prefix=['application_type'], columns=['application_type'])

# %%
df_clean.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'emp_length', 'annual_inc',
#        'loan_status', 'payment_to_income_ratio_individual', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'term_ 36 months', 'term_ 60 months', 'grade_A', 'grade_B', 'grade_C',
#        'grade_D', 'grade_E', 'grade_F', 'grade_G', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'purpose_car', 'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding',
#        'inversed_mths_since_last_delinq', 'inversed_mths_since_last_record',
#        'inversed_mths_since_last_major_derog', 'income_to_debt_ratio',
#        'application_type_INDIVIDUAL', 'application_type_JOINT'],
#       dtype='object')

# %%
df_clean['loan_status'] = (df_clean['loan_status']=='bad').astype(int)

# %%
df_clean.head(20)
# Out:
#     loan_amnt  int_rate  installment  emp_length  annual_inc  loan_status  \
# 0      5000.0     10.65       162.87        10.0    24000.00            0
# 1      2500.0     15.27        59.83         1.0    30000.00            1
# 2      2400.0     15.96        84.33        10.0    12252.00            0
# 3     10000.0     13.49       339.31        10.0    49200.00            0
# 4      3000.0     12.69        67.79         1.0    80000.00            0
# 5      5000.0      7.90       156.46         3.0    36000.00            0
# 6      7000.0     15.96       170.08         8.0    47004.00            0
# 7      3000.0     18.64       109.43         9.0    48000.00            0
# 8      5600.0     21.28       152.39         4.0    40000.00            1
# 9      5375.0     12.69       121.45         1.0    15000.00            1
# 10     6500.0     14.65       153.45         5.0    72000.00            0
# 11    12000.0     12.69       402.54        10.0    75000.00            0
# 12     9000.0     13.49       305.38         1.0    30000.00            1
# 13     3000.0      9.91        96.68         3.0    15000.00            0
# 14    10000.0     10.65       325.74         3.0   100000.00            1
# 15     1000.0     16.29        35.31         1.0    28000.00            0
# 16    10000.0     15.27       347.98         4.0    42000.00            0
# 17     3600.0      6.03       109.57        10.0   110000.00            0
# 19     9200.0      6.03       280.01         6.0    77385.19            0
# 20    20250.0     15.27       484.63         3.0    43370.00            0
#
#     payment_to_income_ratio_individual  delinq_2yrs  earliest_cr_line  \
# 0                                27.65          0.0                31
# 1                                 1.00          0.0                17
# 2                                 8.72          0.0                15
# 3                                20.00          0.0                20
# 4                                17.94          0.0                20
# 5                                11.20          0.0                12
# 6                                23.51          0.0                11
# 7                                 5.35          0.0                 9
# 8                                 5.55          0.0                12
# 9                                18.08          0.0                12
# 10                               16.12          0.0                18
# 11                               10.78          0.0                27
# 12                               10.08          0.0                12
# 13                               12.56          0.0                13
# 14                                7.06          0.0                25
# 15                               20.31          0.0                 9
# 16                               18.60          0.0                18
# 17                               10.52          0.0                23
# 19                                9.86          0.0                15
# 20                               26.53          0.0                19
#
#     inq_last_6mths           ...            purpose_renewable_energy  \
# 0              1.0           ...                                   0
# 1              5.0           ...                                   0
# 2              2.0           ...                                   0
# 3              1.0           ...                                   0
# 4              0.0           ...                                   0
# 5              3.0           ...                                   0
# 6              1.0           ...                                   0
# 7              2.0           ...                                   0
# 8              2.0           ...                                   0
# 9              0.0           ...                                   0
# 10             2.0           ...                                   0
# 11             0.0           ...                                   0
# 12             1.0           ...                                   0
# 13             2.0           ...                                   0
# 14             2.0           ...                                   0
# 15             1.0           ...                                   0
# 16             2.0           ...                                   0
# 17             0.0           ...                                   0
# 19             0.0           ...                                   0
# 20             3.0           ...                                   0
#
#     purpose_small_business  purpose_vacation  purpose_wedding  \
# 0                        0                 0                0
# 1                        0                 0                0
# 2                        1                 0                0
# 3                        0                 0                0
# 4                        0                 0                0
# 5                        0                 0                1
# 6                        0                 0                0
# 7                        0                 0                0
# 8                        1                 0                0
# 9                        0                 0                0
# 10                       0                 0                0
# 11                       0                 0                0
# 12                       0                 0                0
# 13                       0                 0                0
# 14                       0                 0                0
# 15                       0                 0                0
# 16                       0                 0                0
# 17                       0                 0                0
# 19                       0                 0                0
# 20                       0                 0                0
#
#     inversed_mths_since_last_delinq  inversed_mths_since_last_record  \
# 0                          0.000000                              0.0
# 1                          0.000000                              0.0
# 2                          0.000000                              0.0
# 3                          0.028571                              0.0
# 4                          0.026316                              0.0
# 5                          0.000000                              0.0
# 6                          0.000000                              0.0
# 7                          0.000000                              0.0
# 8                          0.000000                              0.0
# 9                          0.000000                              0.0
# 10                         0.000000                              0.0
# 11                         0.000000                              0.0
# 12                         0.000000                              0.0
# 13                         0.000000                              0.0
# 14                         0.000000                              0.0
# 15                         0.000000                              0.0
# 16                         0.016393                              0.0
# 17                         0.000000                              0.0
# 19                         0.000000                              0.0
# 20                         0.000000                              0.0
#
#     inversed_mths_since_last_major_derog  income_to_debt_ratio  \
# 0                                    0.0              1.758499
# 1                                    0.0             17.783047
# 2                                    0.0              4.144790
# 3                                    0.0              8.788853
# 4                                    0.0              2.879459
# 5                                    0.0              4.520909
# 6                                    0.0              2.651698
# 7                                    0.0              5.838706
# 8                                    0.0              7.677543
# 9                                    0.0              1.616554
# 10                                   0.0             17.857143
# 11                                   0.0              3.213918
# 12                                   0.0              2.870264
# 13                                   0.0              2.048341
# 14                                   0.0              8.335417
# 15                                   0.0              4.291845
# 16                                   0.0              1.746870
# 17                                   0.0              4.816956
# 19                                   0.0             10.580420
# 20                                   0.0              2.434739
#
#     application_type_INDIVIDUAL  application_type_JOINT
# 0                             1                       0
# 1                             1                       0
# 2                             1                       0
# 3                             1                       0
# 4                             1                       0
# 5                             1                       0
# 6                             1                       0
# 7                             1                       0
# 8                             1                       0
# 9                             1                       0
# 10                            1                       0
# 11                            1                       0
# 12                            1                       0
# 13                            1                       0
# 14                            1                       0
# 15                            1                       0
# 16                            1                       0
# 17                            1                       0
# 19                            1                       0
# 20                            1                       0
#
# [20 rows x 55 columns]

# %%
df_clean.corr()
# Out:
#                                       loan_amnt  int_rate  installment  \
# loan_amnt                              1.000000  0.145413     0.944812
# int_rate                               0.145413  1.000000     0.133254
# installment                            0.944812  0.133254     1.000000
# emp_length                             0.103315  0.009411     0.087992
# annual_inc                             0.332569 -0.072979     0.325900
# loan_status                            0.005463  0.176271     0.016039
# payment_to_income_ratio_individual     0.019483  0.079449     0.013205
# delinq_2yrs                            0.000317  0.055138     0.008330
# earliest_cr_line                       0.169350 -0.104494     0.150521
# inq_last_6mths                        -0.028376  0.232718     0.002401
# open_acc                               0.197514 -0.010087     0.182372
# pub_rec                               -0.082398  0.051974    -0.071137
# revol_bal                              0.336987 -0.036052     0.319246
# revol_util                             0.117969  0.271797     0.130340
# collections_12_mths_ex_med            -0.017058  0.013658    -0.014523
# policy_code                                 NaN       NaN          NaN
# acc_now_delinq                         0.003881  0.026559     0.006473
# tot_coll_amt                          -0.003563  0.001387    -0.002865
# tot_cur_bal                            0.317011 -0.088112     0.286985
# total_rev_hi_lim                       0.300406 -0.159873     0.275607
# term_ 36 months                       -0.411676 -0.428755    -0.144371
# term_ 60 months                        0.411676  0.428755     0.144371
# grade_A                               -0.038315 -0.613721    -0.016807
# grade_B                               -0.084764 -0.349646    -0.074217
# grade_C                               -0.021878  0.104371    -0.038251
# grade_D                                0.036845  0.388071     0.033964
# grade_E                                0.115068  0.447571     0.096088
# grade_F                                0.085910  0.385703     0.086999
# grade_G                                0.056163  0.222987     0.063158
# home_ownership_ANY                     0.001390  0.000415     0.001581
# home_ownership_MORTGAGE                0.192065 -0.061022     0.159471
# home_ownership_NONE                   -0.000592  0.002926     0.000647
# home_ownership_OTHER                  -0.004288 -0.000210    -0.002750
# home_ownership_OWN                    -0.021168  0.001763    -0.017183
# home_ownership_RENT                   -0.182943  0.061136    -0.152174
# purpose_car                           -0.069400 -0.028069    -0.069325
# purpose_credit_card                    0.036990 -0.185278     0.027965
# purpose_debt_consolidation             0.094274  0.097422     0.092508
# purpose_educational                   -0.017559 -0.006714    -0.016664
# purpose_home_improvement              -0.012896 -0.012189    -0.016884
# purpose_house                          0.001080  0.041654     0.006572
# purpose_major_purchase                -0.052007 -0.018141    -0.052739
# purpose_medical                       -0.066701  0.029640    -0.062800
# purpose_moving                        -0.063403  0.044584    -0.057828
# purpose_other                         -0.128466  0.092193    -0.116290
# purpose_renewable_energy              -0.014173  0.012860    -0.012090
# purpose_small_business                 0.008769  0.074271     0.022200
# purpose_vacation                      -0.073101  0.018685    -0.069483
# purpose_wedding                       -0.025564  0.010759    -0.021585
# inversed_mths_since_last_delinq        0.014590  0.051977     0.020735
# inversed_mths_since_last_record       -0.040086  0.026934    -0.033768
# inversed_mths_since_last_major_derog  -0.017115  0.042863    -0.010531
# income_to_debt_ratio                  -0.003100 -0.004582    -0.002656
# application_type_INDIVIDUAL           -0.011012 -0.009636    -0.009004
# application_type_JOINT                 0.011012  0.009636     0.009004
#
#                                       emp_length  annual_inc  loan_status  \
# loan_amnt                               0.103315    0.332569     0.005463
# int_rate                                0.009411   -0.072979     0.176271
# installment                             0.087992    0.325900     0.016039
# emp_length                              1.000000    0.062809    -0.015148
# annual_inc                              0.062809    1.000000    -0.034007
# loan_status                            -0.015148   -0.034007     1.000000
# payment_to_income_ratio_individual      0.019743   -0.087226     0.010962
# delinq_2yrs                             0.024928    0.047715     0.003177
# earliest_cr_line                        0.207999    0.143974    -0.018992
# inq_last_6mths                         -0.006142    0.037144     0.073945
# open_acc                                0.037257    0.138005    -0.014625
# pub_rec                                 0.030493   -0.008750    -0.013110
# revol_bal                               0.086902    0.296143    -0.021951
# revol_util                              0.033329    0.036825     0.051576
# collections_12_mths_ex_med             -0.003903   -0.003839    -0.006451
# policy_code                                  NaN         NaN          NaN
# acc_now_delinq                          0.009130    0.014717     0.000229
# tot_coll_amt                           -0.000284    0.001215    -0.001946
# tot_cur_bal                             0.092965    0.405875    -0.035223
# total_rev_hi_lim                        0.072761    0.260973    -0.036694
# term_ 36 months                        -0.067256   -0.058520    -0.040696
# term_ 60 months                         0.067256    0.058520     0.040696
# grade_A                                -0.003489    0.082663    -0.086461
# grade_B                                -0.001405    0.004431    -0.055014
# grade_C                                 0.000529   -0.033773     0.004129
# grade_D                                -0.000898   -0.039000     0.061359
# grade_E                                 0.003945   -0.012865     0.068427
# grade_F                                 0.005162   -0.003022     0.069778
# grade_G                                 0.001866    0.005465     0.044486
# home_ownership_ANY                      0.000663   -0.000323    -0.000532
# home_ownership_MORTGAGE                 0.186772    0.155227    -0.034140
# home_ownership_NONE                     0.001275   -0.001272     0.002156
# home_ownership_OTHER                   -0.004065   -0.001138     0.005679
# home_ownership_OWN                      0.020794   -0.031262    -0.004578
# home_ownership_RENT                    -0.203070   -0.139298     0.037431
# purpose_car                            -0.018408   -0.010880    -0.003461
# purpose_credit_card                    -0.021042    0.000392    -0.038774
# purpose_debt_consolidation              0.026913   -0.021075     0.016717
# purpose_educational                    -0.012548   -0.006281     0.006669
# purpose_home_improvement                0.033321    0.058416    -0.007380
# purpose_house                          -0.011411    0.005677     0.008735
# purpose_major_purchase                 -0.019462    0.003917    -0.000857
# purpose_medical                        -0.002753   -0.004090     0.006432
# purpose_moving                         -0.033744   -0.007941     0.010515
# purpose_other                          -0.005953   -0.018186     0.016731
# purpose_renewable_energy                0.000433   -0.000428     0.004448
# purpose_small_business                 -0.016398    0.024453     0.037346
# purpose_vacation                        0.004387   -0.008886     0.002349
# purpose_wedding                        -0.022119   -0.004412     0.008742
# inversed_mths_since_last_delinq         0.031750    0.048312     0.000458
# inversed_mths_since_last_record         0.014264    0.006686    -0.009653
# inversed_mths_since_last_major_derog    0.019594    0.017940    -0.004193
# income_to_debt_ratio                   -0.004619    0.020773     0.001053
# application_type_INDIVIDUAL            -0.000534    0.006152     0.005535
# application_type_JOINT                  0.000534   -0.006152    -0.005535
#
#                                       payment_to_income_ratio_individual  \
# loan_amnt                                                       0.019483
# int_rate                                                        0.079449
# installment                                                     0.013205
# emp_length                                                      0.019743
# annual_inc                                                     -0.087226
# loan_status                                                     0.010962
# payment_to_income_ratio_individual                              1.000000
# delinq_2yrs                                                    -0.002928
# earliest_cr_line                                                0.013093
# inq_last_6mths                                                 -0.005728
# open_acc                                                        0.141913
# pub_rec                                                        -0.023261
# revol_bal                                                       0.066460
# revol_util                                                      0.084994
# collections_12_mths_ex_med                                     -0.000280
# policy_code                                                          NaN
# acc_now_delinq                                                  0.003161
# tot_coll_amt                                                   -0.001669
# tot_cur_bal                                                    -0.007262
# total_rev_hi_lim                                                0.032004
# term_ 36 months                                                -0.050432
# term_ 60 months                                                 0.050432
# grade_A                                                        -0.066895
# grade_B                                                        -0.031547
# grade_C                                                         0.022624
# grade_D                                                         0.044077
# grade_E                                                         0.037502
# grade_F                                                         0.016138
# grade_G                                                         0.004832
# home_ownership_ANY                                              0.000905
# home_ownership_MORTGAGE                                        -0.003490
# home_ownership_NONE                                             0.000245
# home_ownership_OTHER                                           -0.002552
# home_ownership_OWN                                              0.015037
# home_ownership_RENT                                            -0.005518
# purpose_car                                                    -0.021216
# purpose_credit_card                                             0.006356
# purpose_debt_consolidation                                      0.043056
# purpose_educational                                            -0.007230
# purpose_home_improvement                                       -0.036746
# purpose_house                                                  -0.013761
# purpose_major_purchase                                         -0.028122
# purpose_medical                                                -0.005111
# purpose_moving                                                 -0.008772
# purpose_other                                                  -0.016277
# purpose_renewable_energy                                       -0.003371
# purpose_small_business                                         -0.025280
# purpose_vacation                                               -0.004105
# purpose_wedding                                                -0.011941
# inversed_mths_since_last_delinq                                -0.000443
# inversed_mths_since_last_record                                -0.014612
# inversed_mths_since_last_major_derog                           -0.007076
# income_to_debt_ratio                                           -0.013035
# application_type_INDIVIDUAL                                    -0.077614
# application_type_JOINT                                          0.077614
#
#                                       delinq_2yrs  earliest_cr_line  \
# loan_amnt                                0.000317          0.169350
# int_rate                                 0.055138         -0.104494
# installment                              0.008330          0.150521
# emp_length                               0.024928          0.207999
# annual_inc                               0.047715          0.143974
# loan_status                              0.003177         -0.018992
# payment_to_income_ratio_individual      -0.002928          0.013093
# delinq_2yrs                              1.000000          0.082433
# earliest_cr_line                         0.082433          1.000000
# inq_last_6mths                           0.023656          0.011441
# open_acc                                 0.051896          0.128123
# pub_rec                                 -0.011096          0.061258
# revol_bal                               -0.032288          0.206721
# revol_util                              -0.016804          0.004880
# collections_12_mths_ex_med               0.063248          0.001989
# policy_code                                   NaN               NaN
# acc_now_delinq                           0.130529          0.023375
# tot_coll_amt                             0.000559          0.005425
# tot_cur_bal                              0.063995          0.173481
# total_rev_hi_lim                        -0.039990          0.210656
# term_ 36 months                          0.000155         -0.043203
# term_ 60 months                         -0.000155          0.043203
# grade_A                                 -0.066659          0.095103
# grade_B                                 -0.004610          0.034475
# grade_C                                  0.024976         -0.036879
# grade_D                                  0.023681         -0.049788
# grade_E                                  0.017169         -0.039932
# grade_F                                  0.010975         -0.028839
# grade_G                                  0.010103         -0.014198
# home_ownership_ANY                      -0.000676          0.000672
# home_ownership_MORTGAGE                  0.049594          0.174040
# home_ownership_NONE                      0.000160          0.002473
# home_ownership_OTHER                    -0.000248          0.004250
# home_ownership_OWN                      -0.002893          0.045987
# home_ownership_RENT                     -0.048824         -0.205620
# purpose_car                             -0.002224         -0.013518
# purpose_credit_card                     -0.029251          0.012155
# purpose_debt_consolidation               0.010672         -0.001941
# purpose_educational                     -0.003046          0.002115
# purpose_home_improvement                 0.020896          0.032374
# purpose_house                            0.003238         -0.010196
# purpose_major_purchase                  -0.000214         -0.018618
# purpose_medical                          0.004784          0.003466
# purpose_moving                           0.003756         -0.022727
# purpose_other                            0.007628         -0.018029
# purpose_renewable_energy                -0.001585         -0.003512
# purpose_small_business                   0.001766         -0.003588
# purpose_vacation                         0.000763         -0.013280
# purpose_wedding                         -0.004711         -0.011273
# inversed_mths_since_last_delinq          0.462281          0.080949
# inversed_mths_since_last_record          0.010064          0.045098
# inversed_mths_since_last_major_derog     0.294611          0.054440
# income_to_debt_ratio                     0.008382         -0.002352
# application_type_INDIVIDUAL             -0.000858          0.002276
# application_type_JOINT                   0.000858         -0.002276
#
#                                       inq_last_6mths           ...            \
# loan_amnt                                  -0.028376           ...
# int_rate                                    0.232718           ...
# installment                                 0.002401           ...
# emp_length                                 -0.006142           ...
# annual_inc                                  0.037144           ...
# loan_status                                 0.073945           ...
# payment_to_income_ratio_individual         -0.005728           ...
# delinq_2yrs                                 0.023656           ...
# earliest_cr_line                            0.011441           ...
# inq_last_6mths                              1.000000           ...
# open_acc                                    0.117376           ...
# pub_rec                                     0.059911           ...
# revol_bal                                  -0.018916           ...
# revol_util                                 -0.089345           ...
# collections_12_mths_ex_med                  0.007981           ...
# policy_code                                      NaN           ...
# acc_now_delinq                             -0.004755           ...
# tot_coll_amt                                0.002776           ...
# tot_cur_bal                                 0.033016           ...
# total_rev_hi_lim                            0.005345           ...
# term_ 36 months                             0.000906           ...
# term_ 60 months                            -0.000906           ...
# grade_A                                    -0.130803           ...
# grade_B                                    -0.090577           ...
# grade_C                                     0.032116           ...
# grade_D                                     0.091106           ...
# grade_E                                     0.090093           ...
# grade_F                                     0.084546           ...
# grade_G                                     0.058599           ...
# home_ownership_ANY                         -0.000673           ...
# home_ownership_MORTGAGE                     0.036923           ...
# home_ownership_NONE                        -0.001452           ...
# home_ownership_OTHER                        0.003543           ...
# home_ownership_OWN                         -0.002589           ...
# home_ownership_RENT                        -0.036157           ...
# purpose_car                                 0.005529           ...
# purpose_credit_card                        -0.039485           ...
# purpose_debt_consolidation                 -0.009214           ...
# purpose_educational                         0.008076           ...
# purpose_home_improvement                    0.039959           ...
# purpose_house                               0.023461           ...
# purpose_major_purchase                      0.015588           ...
# purpose_medical                             0.007006           ...
# purpose_moving                              0.006513           ...
# purpose_other                               0.009818           ...
# purpose_renewable_energy                    0.003103           ...
# purpose_small_business                      0.029906           ...
# purpose_vacation                            0.006662           ...
# purpose_wedding                             0.011042           ...
# inversed_mths_since_last_delinq            -0.004886           ...
# inversed_mths_since_last_record             0.038563           ...
# inversed_mths_since_last_major_derog        0.025425           ...
# income_to_debt_ratio                        0.003774           ...
# application_type_INDIVIDUAL                 0.002090           ...
# application_type_JOINT                     -0.002090           ...
#
#                                       purpose_renewable_energy  \
# loan_amnt                                            -0.014173
# int_rate                                              0.012860
# installment                                          -0.012090
# emp_length                                            0.000433
# annual_inc                                           -0.000428
# loan_status                                           0.004448
# payment_to_income_ratio_individual                   -0.003371
# delinq_2yrs                                          -0.001585
# earliest_cr_line                                     -0.003512
# inq_last_6mths                                        0.003103
# open_acc                                             -0.006735
# pub_rec                                               0.001155
# revol_bal                                            -0.004039
# revol_util                                           -0.003302
# collections_12_mths_ex_med                           -0.000318
# policy_code                                                NaN
# acc_now_delinq                                       -0.001036
# tot_coll_amt                                         -0.000137
# tot_cur_bal                                          -0.004177
# total_rev_hi_lim                                     -0.003325
# term_ 36 months                                       0.006515
# term_ 60 months                                      -0.006515
# grade_A                                              -0.004583
# grade_B                                              -0.007157
# grade_C                                              -0.001587
# grade_D                                               0.006495
# grade_E                                               0.006565
# grade_F                                               0.007681
# grade_G                                               0.003950
# home_ownership_ANY                                   -0.000047
# home_ownership_MORTGAGE                              -0.004553
# home_ownership_NONE                                  -0.000181
# home_ownership_OTHER                                  0.003301
# home_ownership_OWN                                    0.002215
# home_ownership_RENT                                   0.003217
# purpose_car                                          -0.002509
# purpose_credit_card                                  -0.013899
# purpose_debt_consolidation                           -0.030388
# purpose_educational                                  -0.000471
# purpose_home_improvement                             -0.006250
# purpose_house                                        -0.001614
# purpose_major_purchase                               -0.003516
# purpose_medical                                      -0.002469
# purpose_moving                                       -0.001958
# purpose_other                                        -0.005634
# purpose_renewable_energy                              1.000000
# purpose_small_business                               -0.002704
# purpose_vacation                                     -0.001835
# purpose_wedding                                      -0.001277
# inversed_mths_since_last_delinq                      -0.001015
# inversed_mths_since_last_record                      -0.000202
# inversed_mths_since_last_major_derog                 -0.001359
# income_to_debt_ratio                                  0.000822
# application_type_INDIVIDUAL                           0.000570
# application_type_JOINT                               -0.000570
#
#                                       purpose_small_business  \
# loan_amnt                                           0.008769
# int_rate                                            0.074271
# installment                                         0.022200
# emp_length                                         -0.016398
# annual_inc                                          0.024453
# loan_status                                         0.037346
# payment_to_income_ratio_individual                 -0.025280
# delinq_2yrs                                         0.001766
# earliest_cr_line                                   -0.003588
# inq_last_6mths                                      0.029906
# open_acc                                           -0.030037
# pub_rec                                             0.011118
# revol_bal                                          -0.010598
# revol_util                                         -0.039621
# collections_12_mths_ex_med                          0.001039
# policy_code                                              NaN
# acc_now_delinq                                     -0.000931
# tot_coll_amt                                        0.000660
# tot_cur_bal                                        -0.000620
# total_rev_hi_lim                                   -0.001550
# term_ 36 months                                     0.006098
# term_ 60 months                                    -0.006098
# grade_A                                            -0.024615
# grade_B                                            -0.034669
# grade_C                                            -0.012609
# grade_D                                             0.027193
# grade_E                                             0.038886
# grade_F                                             0.042646
# grade_G                                             0.043544
# home_ownership_ANY                                 -0.000199
# home_ownership_MORTGAGE                            -0.007903
# home_ownership_NONE                                -0.000770
# home_ownership_OTHER                                0.008100
# home_ownership_OWN                                 -0.001095
# home_ownership_RENT                                 0.008531
# purpose_car                                        -0.010681
# purpose_credit_card                                -0.059174
# purpose_debt_consolidation                         -0.129378
# purpose_educational                                -0.002006
# purpose_home_improvement                           -0.026607
# purpose_house                                      -0.006873
# purpose_major_purchase                             -0.014967
# purpose_medical                                    -0.010512
# purpose_moving                                     -0.008338
# purpose_other                                      -0.023986
# purpose_renewable_energy                           -0.002704
# purpose_small_business                              1.000000
# purpose_vacation                                   -0.007811
# purpose_wedding                                    -0.005436
# inversed_mths_since_last_delinq                     0.003171
# inversed_mths_since_last_record                     0.009321
# inversed_mths_since_last_major_derog               -0.001483
# income_to_debt_ratio                                0.009482
# application_type_INDIVIDUAL                         0.001951
# application_type_JOINT                             -0.001951
#
#                                       purpose_vacation  purpose_wedding  \
# loan_amnt                                    -0.073101        -0.025564
# int_rate                                      0.018685         0.010759
# installment                                  -0.069483        -0.021585
# emp_length                                    0.004387        -0.022119
# annual_inc                                   -0.008886        -0.004412
# loan_status                                   0.002349         0.008742
# payment_to_income_ratio_individual           -0.004105        -0.011941
# delinq_2yrs                                   0.000763        -0.004711
# earliest_cr_line                             -0.013280        -0.011273
# inq_last_6mths                                0.006662         0.011042
# open_acc                                     -0.014745        -0.017095
# pub_rec                                       0.001821        -0.012167
# revol_bal                                    -0.018397        -0.014118
# revol_util                                   -0.015942        -0.015436
# collections_12_mths_ex_med                   -0.001175        -0.005283
# policy_code                                        NaN              NaN
# acc_now_delinq                               -0.001633        -0.002968
# tot_coll_amt                                  0.000120        -0.000883
# tot_cur_bal                                  -0.016076        -0.005480
# total_rev_hi_lim                             -0.014915        -0.003862
# term_ 36 months                               0.034135         0.014851
# term_ 60 months                              -0.034135        -0.014851
# grade_A                                      -0.014550         0.003734
# grade_B                                      -0.012565        -0.005773
# grade_C                                       0.009184        -0.007887
# grade_D                                       0.016387         0.008587
# grade_E                                       0.003901         0.001893
# grade_F                                       0.000454         0.005793
# grade_G                                      -0.001127         0.002545
# home_ownership_ANY                           -0.000135        -0.000094
# home_ownership_MORTGAGE                      -0.020799        -0.018937
# home_ownership_NONE                          -0.000523        -0.000364
# home_ownership_OTHER                         -0.000915        -0.000637
# home_ownership_OWN                            0.003416        -0.005698
# home_ownership_RENT                           0.019173         0.022801
# purpose_car                                  -0.007248        -0.005044
# purpose_credit_card                          -0.040152        -0.027943
# purpose_debt_consolidation                   -0.087788        -0.061095
# purpose_educational                          -0.001361        -0.000947
# purpose_home_improvement                     -0.018054        -0.012565
# purpose_house                                -0.004664        -0.003246
# purpose_major_purchase                       -0.010156        -0.007068
# purpose_medical                              -0.007133        -0.004964
# purpose_moving                               -0.005657        -0.003937
# purpose_other                                -0.016275        -0.011327
# purpose_renewable_energy                     -0.001835        -0.001277
# purpose_small_business                       -0.007811        -0.005436
# purpose_vacation                              1.000000        -0.003688
# purpose_wedding                              -0.003688         1.000000
# inversed_mths_since_last_delinq              -0.000589        -0.005496
# inversed_mths_since_last_record               0.000259        -0.008185
# inversed_mths_since_last_major_derog          0.001931        -0.008708
# income_to_debt_ratio                          0.001524         0.009011
# application_type_INDIVIDUAL                   0.000949         0.001147
# application_type_JOINT                       -0.000949        -0.001147
#
#                                       inversed_mths_since_last_delinq  \
# loan_amnt                                                    0.014590
# int_rate                                                     0.051977
# installment                                                  0.020735
# emp_length                                                   0.031750
# annual_inc                                                   0.048312
# loan_status                                                  0.000458
# payment_to_income_ratio_individual                          -0.000443
# delinq_2yrs                                                  0.462281
# earliest_cr_line                                             0.080949
# inq_last_6mths                                              -0.004886
# open_acc                                                     0.052000
# pub_rec                                                     -0.015305
# revol_bal                                                   -0.016219
# revol_util                                                  -0.046916
# collections_12_mths_ex_med                                   0.038922
# policy_code                                                       NaN
# acc_now_delinq                                               0.506679
# tot_coll_amt                                                 0.001378
# tot_cur_bal                                                  0.072225
# total_rev_hi_lim                                            -0.006253
# term_ 36 months                                             -0.009384
# term_ 60 months                                              0.009384
# grade_A                                                     -0.059743
# grade_B                                                     -0.004667
# grade_C                                                      0.020682
# grade_D                                                      0.019561
# grade_E                                                      0.018980
# grade_F                                                      0.012424
# grade_G                                                      0.012026
# home_ownership_ANY                                          -0.000225
# home_ownership_MORTGAGE                                      0.056608
# home_ownership_NONE                                         -0.000100
# home_ownership_OTHER                                        -0.001383
# home_ownership_OWN                                           0.000133
# home_ownership_RENT                                         -0.057786
# purpose_car                                                 -0.004117
# purpose_credit_card                                         -0.024965
# purpose_debt_consolidation                                   0.011831
# purpose_educational                                         -0.003472
# purpose_home_improvement                                     0.017510
# purpose_house                                                0.000888
# purpose_major_purchase                                      -0.001768
# purpose_medical                                              0.003400
# purpose_moving                                               0.000663
# purpose_other                                                0.004404
# purpose_renewable_energy                                    -0.001015
# purpose_small_business                                       0.003171
# purpose_vacation                                            -0.000589
# purpose_wedding                                             -0.005496
# inversed_mths_since_last_delinq                              1.000000
# inversed_mths_since_last_record                             -0.001120
# inversed_mths_since_last_major_derog                         0.414841
# income_to_debt_ratio                                         0.005493
# application_type_INDIVIDUAL                                 -0.001039
# application_type_JOINT                                       0.001039
#
#                                       inversed_mths_since_last_record  \
# loan_amnt                                                   -0.040086
# int_rate                                                     0.026934
# installment                                                 -0.033768
# emp_length                                                   0.014264
# annual_inc                                                   0.006686
# loan_status                                                 -0.009653
# payment_to_income_ratio_individual                          -0.014612
# delinq_2yrs                                                  0.010064
# earliest_cr_line                                             0.045098
# inq_last_6mths                                               0.038563
# open_acc                                                    -0.013502
# pub_rec                                                      0.470443
# revol_bal                                                   -0.052965
# revol_util                                                  -0.057901
# collections_12_mths_ex_med                                   0.015030
# policy_code                                                       NaN
# acc_now_delinq                                               0.007216
# tot_coll_amt                                                 0.004780
# tot_cur_bal                                                 -0.031416
# total_rev_hi_lim                                            -0.050039
# term_ 36 months                                              0.014242
# term_ 60 months                                             -0.014242
# grade_A                                                     -0.043025
# grade_B                                                     -0.000767
# grade_C                                                      0.018860
# grade_D                                                      0.013659
# grade_E                                                      0.008884
# grade_F                                                      0.002227
# grade_G                                                      0.003004
# home_ownership_ANY                                          -0.000389
# home_ownership_MORTGAGE                                     -0.000552
# home_ownership_NONE                                         -0.001506
# home_ownership_OTHER                                        -0.002445
# home_ownership_OWN                                           0.003236
# home_ownership_RENT                                         -0.001317
# purpose_car                                                 -0.000306
# purpose_credit_card                                         -0.019930
# purpose_debt_consolidation                                   0.000517
# purpose_educational                                         -0.003080
# purpose_home_improvement                                     0.023896
# purpose_house                                                0.001699
# purpose_major_purchase                                       0.001400
# purpose_medical                                              0.002372
# purpose_moving                                               0.000077
# purpose_other                                                0.007300
# purpose_renewable_energy                                    -0.000202
# purpose_small_business                                       0.009321
# purpose_vacation                                             0.000259
# purpose_wedding                                             -0.008185
# inversed_mths_since_last_delinq                             -0.001120
# inversed_mths_since_last_record                              1.000000
# inversed_mths_since_last_major_derog                         0.025661
# income_to_debt_ratio                                         0.003609
# application_type_INDIVIDUAL                                 -0.000702
# application_type_JOINT                                       0.000702
#
#                                       inversed_mths_since_last_major_derog  \
# loan_amnt                                                        -0.017115
# int_rate                                                          0.042863
# installment                                                      -0.010531
# emp_length                                                        0.019594
# annual_inc                                                        0.017940
# loan_status                                                      -0.004193
# payment_to_income_ratio_individual                               -0.007076
# delinq_2yrs                                                       0.294611
# earliest_cr_line                                                  0.054440
# inq_last_6mths                                                    0.025425
# open_acc                                                          0.008626
# pub_rec                                                           0.023308
# revol_bal                                                        -0.041916
# revol_util                                                       -0.028157
# collections_12_mths_ex_med                                        0.117049
# policy_code                                                            NaN
# acc_now_delinq                                                    0.322663
# tot_coll_amt                                                      0.006598
# tot_cur_bal                                                       0.015318
# total_rev_hi_lim                                                 -0.045175
# term_ 36 months                                                   0.003863
# term_ 60 months                                                  -0.003863
# grade_A                                                          -0.050948
# grade_B                                                          -0.003056
# grade_C                                                           0.018110
# grade_D                                                           0.018043
# grade_E                                                           0.016362
# grade_F                                                           0.005867
# grade_G                                                           0.004745
# home_ownership_ANY                                                0.000280
# home_ownership_MORTGAGE                                           0.007621
# home_ownership_NONE                                               0.000371
# home_ownership_OTHER                                             -0.002696
# home_ownership_OWN                                               -0.003392
# home_ownership_RENT                                              -0.005650
# purpose_car                                                      -0.002693
# purpose_credit_card                                              -0.022046
# purpose_debt_consolidation                                        0.008615
# purpose_educational                                              -0.004834
# purpose_home_improvement                                          0.018302
# purpose_house                                                     0.002971
# purpose_major_purchase                                           -0.000095
# purpose_medical                                                   0.002028
# purpose_moving                                                    0.002921
# purpose_other                                                     0.004991
# purpose_renewable_energy                                         -0.001359
# purpose_small_business                                           -0.001483
# purpose_vacation                                                  0.001931
# purpose_wedding                                                  -0.008708
# inversed_mths_since_last_delinq                                   0.414841
# inversed_mths_since_last_record                                   0.025661
# inversed_mths_since_last_major_derog                              1.000000
# income_to_debt_ratio                                              0.006937
# application_type_INDIVIDUAL                                      -0.000182
# application_type_JOINT                                            0.000182
#
#                                       income_to_debt_ratio  \
# loan_amnt                                        -0.003100
# int_rate                                         -0.004582
# installment                                      -0.002656
# emp_length                                       -0.004619
# annual_inc                                        0.020773
# loan_status                                       0.001053
# payment_to_income_ratio_individual               -0.013035
# delinq_2yrs                                       0.008382
# earliest_cr_line                                 -0.002352
# inq_last_6mths                                    0.003774
# open_acc                                         -0.015885
# pub_rec                                           0.004299
# revol_bal                                        -0.020635
# revol_util                                       -0.054338
# collections_12_mths_ex_med                        0.000091
# policy_code                                            NaN
# acc_now_delinq                                    0.001658
# tot_coll_amt                                      0.000529
# tot_cur_bal                                       0.002698
# total_rev_hi_lim                                 -0.009430
# term_ 36 months                                   0.004078
# term_ 60 months                                  -0.004078
# grade_A                                           0.007727
# grade_B                                          -0.002948
# grade_C                                          -0.001679
# grade_D                                          -0.002446
# grade_E                                          -0.000381
# grade_F                                           0.000697
# grade_G                                           0.001116
# home_ownership_ANY                               -0.000041
# home_ownership_MORTGAGE                          -0.000824
# home_ownership_NONE                              -0.000186
# home_ownership_OTHER                              0.000188
# home_ownership_OWN                                0.000440
# home_ownership_RENT                               0.000571
# purpose_car                                       0.006431
# purpose_credit_card                              -0.011403
# purpose_debt_consolidation                       -0.010582
# purpose_educational                               0.001267
# purpose_home_improvement                          0.013532
# purpose_house                                     0.006198
# purpose_major_purchase                            0.012810
# purpose_medical                                   0.009126
# purpose_moving                                    0.006379
# purpose_other                                     0.005091
# purpose_renewable_energy                          0.000822
# purpose_small_business                            0.009482
# purpose_vacation                                  0.001524
# purpose_wedding                                   0.009011
# inversed_mths_since_last_delinq                   0.005493
# inversed_mths_since_last_record                   0.003609
# inversed_mths_since_last_major_derog              0.006937
# income_to_debt_ratio                              1.000000
# application_type_INDIVIDUAL                       0.000329
# application_type_JOINT                           -0.000329
#
#                                       application_type_INDIVIDUAL  \
# loan_amnt                                               -0.011012
# int_rate                                                -0.009636
# installment                                             -0.009004
# emp_length                                              -0.000534
# annual_inc                                               0.006152
# loan_status                                              0.005535
# payment_to_income_ratio_individual                      -0.077614
# delinq_2yrs                                             -0.000858
# earliest_cr_line                                         0.002276
# inq_last_6mths                                           0.002090
# open_acc                                                 0.003016
# pub_rec                                                 -0.003450
# revol_bal                                                0.001794
# revol_util                                              -0.007509
# collections_12_mths_ex_med                              -0.000610
# policy_code                                                   NaN
# acc_now_delinq                                           0.000805
# tot_coll_amt                                            -0.000092
# tot_cur_bal                                             -0.003926
# total_rev_hi_lim                                         0.004662
# term_ 36 months                                          0.010986
# term_ 60 months                                         -0.010986
# grade_A                                                  0.007968
# grade_B                                                  0.004526
# grade_C                                                 -0.000571
# grade_D                                                 -0.005256
# grade_E                                                 -0.007589
# grade_F                                                 -0.002716
# grade_G                                                 -0.004817
# home_ownership_ANY                                       0.000042
# home_ownership_MORTGAGE                                 -0.007946
# home_ownership_NONE                                      0.000163
# home_ownership_OTHER                                     0.000285
# home_ownership_OWN                                       0.002035
# home_ownership_RENT                                      0.006859
# purpose_car                                              0.001740
# purpose_credit_card                                      0.000270
# purpose_debt_consolidation                              -0.002797
# purpose_educational                                      0.000423
# purpose_home_improvement                                 0.001278
# purpose_house                                            0.001450
# purpose_major_purchase                                   0.002418
# purpose_medical                                          0.001174
# purpose_moving                                           0.001103
# purpose_other                                           -0.000885
# purpose_renewable_energy                                 0.000570
# purpose_small_business                                   0.001951
# purpose_vacation                                         0.000949
# purpose_wedding                                          0.001147
# inversed_mths_since_last_delinq                         -0.001039
# inversed_mths_since_last_record                         -0.000702
# inversed_mths_since_last_major_derog                    -0.000182
# income_to_debt_ratio                                     0.000329
# application_type_INDIVIDUAL                              1.000000
# application_type_JOINT                                  -1.000000
#
#                                       application_type_JOINT
# loan_amnt                                           0.011012
# int_rate                                            0.009636
# installment                                         0.009004
# emp_length                                          0.000534
# annual_inc                                         -0.006152
# loan_status                                        -0.005535
# payment_to_income_ratio_individual                  0.077614
# delinq_2yrs                                         0.000858
# earliest_cr_line                                   -0.002276
# inq_last_6mths                                     -0.002090
# open_acc                                           -0.003016
# pub_rec                                             0.003450
# revol_bal                                          -0.001794
# revol_util                                          0.007509
# collections_12_mths_ex_med                          0.000610
# policy_code                                              NaN
# acc_now_delinq                                     -0.000805
# tot_coll_amt                                        0.000092
# tot_cur_bal                                         0.003926
# total_rev_hi_lim                                   -0.004662
# term_ 36 months                                    -0.010986
# term_ 60 months                                     0.010986
# grade_A                                            -0.007968
# grade_B                                            -0.004526
# grade_C                                             0.000571
# grade_D                                             0.005256
# grade_E                                             0.007589
# grade_F                                             0.002716
# grade_G                                             0.004817
# home_ownership_ANY                                 -0.000042
# home_ownership_MORTGAGE                             0.007946
# home_ownership_NONE                                -0.000163
# home_ownership_OTHER                               -0.000285
# home_ownership_OWN                                 -0.002035
# home_ownership_RENT                                -0.006859
# purpose_car                                        -0.001740
# purpose_credit_card                                -0.000270
# purpose_debt_consolidation                          0.002797
# purpose_educational                                -0.000423
# purpose_home_improvement                           -0.001278
# purpose_house                                      -0.001450
# purpose_major_purchase                             -0.002418
# purpose_medical                                    -0.001174
# purpose_moving                                     -0.001103
# purpose_other                                       0.000885
# purpose_renewable_energy                           -0.000570
# purpose_small_business                             -0.001951
# purpose_vacation                                   -0.000949
# purpose_wedding                                    -0.001147
# inversed_mths_since_last_delinq                     0.001039
# inversed_mths_since_last_record                     0.000702
# inversed_mths_since_last_major_derog                0.000182
# income_to_debt_ratio                               -0.000329
# application_type_INDIVIDUAL                        -1.000000
# application_type_JOINT                              1.000000
#
# [55 rows x 55 columns]

# %%
df_clean.corr().loan_status.sort_values(ascending=False)[1:]
# Out:
# int_rate                                0.176271
# inq_last_6mths                          0.073945
# grade_F                                 0.069778
# grade_E                                 0.068427
# grade_D                                 0.061359
# revol_util                              0.051576
# grade_G                                 0.044486
# term_ 60 months                         0.040696
# home_ownership_RENT                     0.037431
# purpose_small_business                  0.037346
# purpose_other                           0.016731
# purpose_debt_consolidation              0.016717
# installment                             0.016039
# payment_to_income_ratio_individual      0.010962
# purpose_moving                          0.010515
# purpose_wedding                         0.008742
# purpose_house                           0.008735
# purpose_educational                     0.006669
# purpose_medical                         0.006432
# home_ownership_OTHER                    0.005679
# application_type_INDIVIDUAL             0.005535
# loan_amnt                               0.005463
# purpose_renewable_energy                0.004448
# grade_C                                 0.004129
# delinq_2yrs                             0.003177
# purpose_vacation                        0.002349
# home_ownership_NONE                     0.002156
# income_to_debt_ratio                    0.001053
# inversed_mths_since_last_delinq         0.000458
# acc_now_delinq                          0.000229
# home_ownership_ANY                     -0.000532
# purpose_major_purchase                 -0.000857
# tot_coll_amt                           -0.001946
# purpose_car                            -0.003461
# inversed_mths_since_last_major_derog   -0.004193
# home_ownership_OWN                     -0.004578
# application_type_JOINT                 -0.005535
# collections_12_mths_ex_med             -0.006451
# purpose_home_improvement               -0.007380
# inversed_mths_since_last_record        -0.009653
# pub_rec                                -0.013110
# open_acc                               -0.014625
# emp_length                             -0.015148
# earliest_cr_line                       -0.018992
# revol_bal                              -0.021951
# annual_inc                             -0.034007
# home_ownership_MORTGAGE                -0.034140
# tot_cur_bal                            -0.035223
# total_rev_hi_lim                       -0.036694
# purpose_credit_card                    -0.038774
# term_ 36 months                        -0.040696
# grade_B                                -0.055014
# grade_A                                -0.086461
# policy_code                                  NaN
# Name: loan_status, dtype: float64

# %%
pkl_path= './data/loan_preprocessed.pkl'

with open(pkl_path, 'wb') as pklfile:
    pickle.dump(df_clean, pklfile)
