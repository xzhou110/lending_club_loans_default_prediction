# %%
import pandas as pd
import numpy as np
import csv
import sqlite3
import re
import pickle
import itertools

from sklearn.dummy import DummyClassifier
from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

from imblearn.under_sampling import RandomUnderSampler

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn')

# %%
pkl_filename= '/Users/xzhou/github/project_files/lending_club/loan_final.pkl'

with open(pkl_filename, 'rb') as pklfile:
    df=pd.read_pickle(pkl_filename)

# %%
df.shape
# Out:
# (872926, 47)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'emp_length', 'annual_inc', 'loan_status',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'acc_now_delinq',
#        'term_ 36 months', 'term_ 60 months', 'grade_A', 'grade_B', 'grade_C',
#        'grade_D', 'grade_E', 'grade_F', 'grade_G', 'home_ownership_mortgage',
#        'home_ownership_others', 'home_ownership_own', 'home_ownership_rent',
#        'purpose_car', 'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding',
#        'inversed_mths_since_last_delinq', 'inversed_mths_since_last_record',
#        'income_to_debt_ratio', 'application_type_INDIVIDUAL',
#        'application_type_JOINT'],
#       dtype='object')

# %%
# Noted loan_status is highly imbalanced. good vs. bad = 12 : 1

df.groupby('loan_status').count()
# Out:
#              loan_amnt  int_rate  emp_length  annual_inc  delinq_2yrs  \
# loan_status
# bad              66325     66325       66325       66325        66325
# good            806601    806601      806601      806601       806601
#
#              earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# loan_status
# bad                     66325           66325                   66325
# good                   806601          806601                  806601
#
#              mths_since_last_record  open_acc           ...            \
# loan_status                                             ...
# bad                           66325     66325           ...
# good                         806601    806601           ...
#
#              purpose_other  purpose_renewable_energy  purpose_small_business  \
# loan_status
# bad                  66325                     66325                   66325
# good                806601                    806601                  806601
#
#              purpose_vacation  purpose_wedding  \
# loan_status
# bad                     66325            66325
# good                   806601           806601
#
#              inversed_mths_since_last_delinq  inversed_mths_since_last_record  \
# loan_status
# bad                                    66325                            66325
# good                                  806601                           806601
#
#              income_to_debt_ratio  application_type_INDIVIDUAL  \
# loan_status
# bad                         66325                        66325
# good                       806601                       806601
#
#              application_type_JOINT
# loan_status
# bad                           66325
# good                         806601
#
# [2 rows x 46 columns]

# %%
# Assign bad loan as value 1 and good loan as value 0

df['loan_status'] = (df['loan_status']=='bad').astype(int)

# %%
df.describe(include='all')
# Out:
#            loan_amnt       int_rate     emp_length    annual_inc  \
# count  872926.000000  872926.000000  872926.000000  8.729260e+05
# mean    14779.352803      13.252395       6.101334  7.500838e+04
# std      8427.927252       4.384235       3.444948  6.469140e+04
# min       500.000000       5.320000       1.000000  0.000000e+00
# 25%      8000.000000       9.990000       3.000000  4.500000e+04
# 50%     13000.000000      12.990000       6.098617  6.500000e+04
# 75%     20000.000000      16.200000      10.000000  9.000000e+04
# max     35000.000000      28.990000      10.000000  9.500000e+06
#
#          loan_status    delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# count  872926.000000  872926.000000     872926.000000   872926.000000
# mean        0.075980       0.314092         18.306563        0.684289
# std         0.264966       0.861302          7.432795        0.966162
# min         0.000000       0.000000          4.000000        0.000000
# 25%         0.000000       0.000000         13.000000        0.000000
# 50%         0.000000       0.000000         17.000000        0.000000
# 75%         0.000000       0.000000         22.000000        1.000000
# max         1.000000      39.000000         72.000000        8.000000
#
#        mths_since_last_delinq  mths_since_last_record           ...            \
# count           872926.000000           872926.000000           ...
# mean                16.620124               10.842391           ...
# std                 22.885271               27.672070           ...
# min                  0.000000                0.000000           ...
# 25%                  0.000000                0.000000           ...
# 50%                  0.000000                0.000000           ...
# 75%                 30.000000                0.000000           ...
# max                188.000000              129.000000           ...
#
#        purpose_other  purpose_renewable_energy  purpose_small_business  \
# count  872926.000000             872926.000000           872926.000000
# mean        0.047600                  0.000635                0.011380
# std         0.212918                  0.025184                0.106069
# min         0.000000                  0.000000                0.000000
# 25%         0.000000                  0.000000                0.000000
# 50%         0.000000                  0.000000                0.000000
# 75%         0.000000                  0.000000                0.000000
# max         1.000000                  1.000000                1.000000
#
#        purpose_vacation  purpose_wedding  inversed_mths_since_last_delinq  \
# count     872926.000000    872926.000000                    872926.000000
# mean           0.005272         0.002560                         0.031165
# std            0.072416         0.050535                         0.081515
# min            0.000000         0.000000                         0.000000
# 25%            0.000000         0.000000                         0.000000
# 50%            0.000000         0.000000                         0.000000
# 75%            0.000000         0.000000                         0.031250
# max            1.000000         1.000000                         1.000000
#
#        inversed_mths_since_last_record  income_to_debt_ratio  \
# count                    872926.000000         872926.000000
# mean                          0.003001             24.496675
# std                           0.014310            742.312695
# min                           0.000000              0.000000
# 25%                           0.000000              3.186915
# 50%                           0.000000              5.136547
# 75%                           0.000000              9.139470
# max                           1.000000         225000.000000
#
#        application_type_INDIVIDUAL  application_type_JOINT
# count                872926.000000           872926.000000
# mean                      0.999488                0.000512
# std                       0.022623                0.022623
# min                       0.000000                0.000000
# 25%                       1.000000                0.000000
# 50%                       1.000000                0.000000
# 75%                       1.000000                0.000000
# max                       1.000000                1.000000
#
# [8 rows x 47 columns]

# %%
y = df['loan_status']
X = df.drop('loan_status', axis=1)

# %%
# Undersampling will be applied to X_train. 
# Even a test split 0.1 will give a test_size of 87K

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.1, random_state=99)

# %%
ssX = StandardScaler()
X_train_scaled = ssX.fit_transform(X_train)
X_test_scaled = ssX.transform(X_test)

# %%
# Under sampling was used to handel the inbalance issue

runs = RandomUnderSampler()
X_train_scaled_under, y_train_under = runs.fit_sample(X_train_scaled, y_train)

# %%
X_train_scaled_under.shape
# Out:
# (119390, 46)

# %%
y_train_under.shape
# Out:
# (119390,)

# %%
# Iterate through various models to identify best baseline model

models = [RandomForestClassifier(n_estimators=100, n_jobs=-1, max_depth=10), 
          DecisionTreeClassifier(max_depth=None), 
          BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, n_jobs=-1),
          SVC(probability=True), LogisticRegression(C=0.1), 
          SGDClassifier(loss='log', random_state=42, alpha=0.01)]

model_names = ["Random Forest", "Decision Tree",'Bagging Classifier','SVC','Logistic','SGD-Log']

# %%
model_pkl_filename = '/Users/xzhou/github/project_files/lending_club/loan_model1.pkl'

# %%
# Open the pickle file that stores details for model comparison
# If not existed, create pickle file by runing through various models

roc_plotting=[]

try: 
    with open (model_pkl_filename, 'rb') as pklfile2:
        roc_plotting = pickle.load(pklfile2)    

except: 
    for clf, name in zip(models, model_names):
        clf.fit(X_train_scaled_under, y_train_under)
        y_pred = clf.predict_proba(X_test_scaled)
        fpr, tpr, _ = roc_curve (y_test, y_pred[:, 1])
        auc_score = auc(fpr, tpr)
        roc_plotting.append((name, tpr, fpr, auc_score))
        
        # Store in pickle file if file is not existed
        with open (model_pkl_filename, 'wb') as pklfile2:
            pickle.dump(roc_plotting, pklfile2)

# %%
# Plot ROC curve for model comparison purposes
# Ramdom Forecast was selected as baseline model,
# as it produces best result with an AUC of 0.77

plt.figure(dpi=250)
for name, tpr, fpr, auc_score in roc_plotting:
    plt.plot(fpr, tpr, label=name+' (auc: %.2f)'%auc_score)
plt.plot([0,1], [0,1], color='k', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend (loc='lower right')
plt.title('ROC Curves')
# Out:
# Text(0.5,1,'ROC Curves')

# %%
# Perform GridSearchCV to optmize Random Forest

param_grid = {
    'n_estimators': [100, 300],
    'max_features': ['auto', 'log2'], # auto == sqrt
    'max_depth': [10, 15, 20],
    'criterion': ['gini', 'entropy']
}

# %%
rfc = RandomForestClassifier(random_state=99)

# %%
rf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=4, verbose=2, n_jobs=-1)
rf.fit(X_train_scaled_under, y_train_under)
# Out:
# Fitting 4 folds for each of 24 candidates, totalling 96 fits
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=100, total=  29.6s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=100, total=  30.2s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=100, total=  30.4s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=100, total=  30.8s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=300, total= 1.4min
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=300, total= 1.5min
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=300, total= 1.5min
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=300, total= 1.5min
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=100, total=  23.8s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=100, total=  24.0s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=100, total=  23.5s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=100, total=  23.8s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=300, total= 1.1min
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=300, total= 1.1min
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=300, total= 1.1min
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=300, total= 1.1min
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=100
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=100, total=  32.4s
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=100, total=  32.5s
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=100, total=  32.5s
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=100, total=  32.6s
# [CV] criterion=gini, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=300, total= 1.7min
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=auto, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=100, total=  27.4s
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=100, total=  27.9s
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=100, total=  27.6s
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=100, total=  27.8s
# [CV] criterion=gini, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=100, total=  43.3s
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=300
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  9.1min
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=100, total=  43.7s
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=100, total=  43.6s
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=100, total=  44.0s
# [CV] criterion=gini, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=300, total= 2.2min
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=300, total= 2.2min
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=300, total= 2.1min
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=auto, n_estimators=300, total= 2.2min
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=100, total=  40.0s
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=100, total=  39.8s
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=100, total=  39.7s
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=100, total=  40.1s
# [CV] criterion=gini, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=300, total= 1.8min
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=300, total= 1.8min
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=300, total= 1.8min
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=100
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=100
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=100
# [CV]  criterion=gini, max_depth=20, max_features=log2, n_estimators=300, total= 1.8min
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=100, total=  32.6s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=100, total=  32.8s
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=100, total=  33.0s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=300
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=100, total=  33.5s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=300, total= 1.4min
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=300, total= 1.4min
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=300, total= 1.4min
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=300, total= 1.4min
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=100, total=  28.6s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=100, total=  29.0s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=100, total=  29.0s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=100, total=  28.9s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=300, total= 1.2min
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=300, total= 1.2min
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=300, total= 1.2min
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=300, total= 1.2min
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=100, total=  33.5s
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=100, total=  33.4s
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=100, total=  33.3s
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=100, total=  33.2s
# [CV] criterion=entropy, max_depth=15, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=300, total= 1.8min
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=300, total= 1.8min
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=300, total= 1.8min
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=100
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=auto, n_estimators=300, total= 1.8min
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=100, total=  33.7s
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=100, total=  33.6s
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=100, total=  33.6s
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=100, total=  33.5s
# [CV] criterion=entropy, max_depth=15, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=15, max_features=log2, n_estimators=300, total= 1.6min
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=100
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=100, total=  40.2s
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=100, total=  40.7s
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=100, total=  40.4s
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=100, total=  40.1s
# [CV] criterion=entropy, max_depth=20, max_features=auto, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=300, total= 2.1min
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=300, total= 2.1min
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=300, total= 2.1min
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=20, max_features=auto, n_estimators=300, total= 2.1min
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=100
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=100, total=  34.9s
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=100, total=  34.8s
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=100, total=  34.9s
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=100, total=  34.6s
# [CV] criterion=entropy, max_depth=20, max_features=log2, n_estimators=300
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=300, total= 1.9min
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=300, total= 1.9min
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=300, total= 1.9min
# [CV]  criterion=entropy, max_depth=20, max_features=log2, n_estimators=300, total= 1.9min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed: 28.8min finished
# GridSearchCV(cv=4, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=99, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [100, 300], 'max_features': ['auto', 'log2'], 'max_depth': [10, 15, 20], 'criterion': ['gini', 'entropy']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
rf.best_score_
# Out:
# 0.6656755172124968

# %%
rf.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#             oob_score=False, random_state=99, verbose=0, warm_start=False)

# %%
y_pred2_soft = rf.predict_proba(X_test_scaled)

# %%
roc_plotting2 = []
fpr2, tpr2, _ = roc_curve (y_test, y_pred2_soft[:, 1])
auc_score2 = auc(fpr2, tpr2)
roc_plotting2.append(( tpr2, fpr2, auc_score2))

# %%
# Plot ROC curve for the optimal hpyer parameters

plt.figure(dpi=250)
for tpr2, fpr2, auc_score2 in roc_plotting2:
    plt.plot(fpr2, tpr2, label='AUC = '+str('.2f'%auc_score2))
plt.plot([0,1], [0,1], color='k', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend (loc='lower right')
plt.title('ROC Curves')
# Out:
# Text(0.5,1,'ROC Curves')

# %%
rf_best = RandomForestClassifier(
    max_depth=20, max_features='auto', n_estimators=300, 
    criterion='entropy',random_state=99)

# %%
rf_best.fit(X_train_scaled_under, y_train_under)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#             oob_score=False, random_state=99, verbose=0, warm_start=False)

# %%
# Store the model for future use.

model_final_filename= '/Users/xzhou/github/project_files/lending_club/loan_mode_final.pkl'

try: 
    with open(model_final_filename, 'rb') as pklfile:
        model=pickle.load(pklfile)
except:
    with open(model_final_filename, 'wb') as pklfile:
        pickle.dump(rf_best, pklfile)

# %%
y_pred3=rf.predict(X_test_scaled)

# %%
# Plot for confusion matrix

plt.figure(figsize=[8,5], dpi=300)
cm = confusion_matrix (y_test, y_pred3)
plt.imshow(cm, cmap=plt.cm.Blues)
plt.colorbar()
plt.xticks([0,1], ['Good', 'Bad'])
plt.yticks([0,1], ['Good', 'Bad'])
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')

fmt = '.2f'
thresh = cm.max() / 2

for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment='center',
             color='white' if cm [i, j] > thresh else 'black')
